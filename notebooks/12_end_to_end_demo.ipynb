# %% [markdown]
# # 12. End-to-end демо
#
# От сырого запроса к структурированному JSON.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from src.data_utils import load_query_clicks, load_sku_desc, FIGURES, ARTIFACTS, ensure_dirs
ensure_dirs()
sns.set_theme(style="whitegrid", context="notebook")
RED, ACCENT, TEAL = "#E31E24", "#0984E3", "#00B894"

# %%
from src.service.extractor import QueryEntityExtractor
import json
ext = QueryEntityExtractor.from_artifacts(ARTIFACTS, ROOT/"models")
demo = [
    "айфон 15 pro 256",
    "samsung galaxy buds",
    "стиральная машинка bosch",
    "телевизор 55 дюймов lg oled",
    "яндекс станция мини",
]
rows = [ext.extract(q) for q in demo]
print(json.dumps(rows, ensure_ascii=False, indent=2))
pd.DataFrame([{**{k:r[k] for k in ["query","brand","category","latency_ms"]}, "n_entities":len(r["entities"])} for r in rows])
# Out:
# [
#   {
#     "query": "айфон 15 pro 256",
#     "entities": [
#       {
#         "text": "айфон",
#         "label": "BRAND",
#         "span": [
#           0,
#           5
#         ]
#       }
#     ],
#     "brand": "Apple",
#     "category": null,
#     "attributes": {},
#     "latency_ms": 117.041
#   },
#   {
#     "query": "samsung galaxy buds",
#     "entities": [
#       {
#         "text": "samsung",
#         "label": "BRAND",
#         "span": [
#           0,
#           7
#         ]
#       },
#       {
#         "text": "galaxy",
#         "label": "BRAND",
#         "span": [
#           8,
#           14
#         ]
#       }
#     ],
#     "brand": "Samsung",
#     "category": "смартфон",
#     "attributes": {},
#     "latency_ms": 7.653
#   },
#   {
#     "query": "стиральная машинка bosch",
#     "entities": [
#       {
#         "text": "стиральная машинка",
#         "label": "CATEGORY",
#         "span": [
#           0,
#           18
#         ]
#       },
#       {
#         "text": "bosch",
#         "label": "BRAND",
#         "span": [
#           19,
#           24
#         ]
#       }
#     ],
#     "brand": "Bosch",
#     "category": "стиральная машинка",
#     "attributes": {},
#     "latency_ms": 5.292
#   },
#   {
#     "query": "телевизор 55 дюймов lg oled",
#     "entities": [
#       {
#         "text": "телевизор",
#         "label": "CATEGORY",
#         "span": [
#           0,
#           9
#         ]
#       },
#       {
#         "text": "55 дюймов",
#         "label": "ATTR",
#         "span": [
#           10,
#           19
#         ]
#       },
#       {
#         "text": "lg",
#         "label": "BRAND",
#         "span": [
#           20,
#           22
#         ]
#       }
#     ],
#     "brand": "LG",
#     "category": "телевизор",
#     "attributes": {
#       "size": "55 дюймов"
#     },
#     "latency_ms": 8.081
#   },
#   {
#     "query": "яндекс станция мини",
#     "entities": [
#       {
#         "text": "яндекс",
#         "label": "BRAND",
#         "span": [
#           0,
#           6
#         ]
#       }
#     ],
#     "brand": "Яндекс",
#     "category": "тв",
#     "attributes": {},
#     "latency_ms": 8.421
#   }
# ]
#                          query    brand            category  latency_ms  \
# 0             айфон 15 pro 256    Apple                None     117.041
# 1          samsung galaxy buds  Samsung            смартфон       7.653
# 2     стиральная машинка bosch    Bosch  стиральная машинка       5.292
# 3  телевизор 55 дюймов lg oled       LG           телевизор       8.081
# 4          яндекс станция мини   Яндекс                  тв       8.421
#
#    n_entities
# 0           1
# 1           2
# 2           2
# 3           3
# 4           1
